# %%
# %config Completer.use_jedi = False

# %%
# importing required modules 
import PyPDF2
import wordninja

# %%
file_name = 'Elios 2 - Brochure EN LW.pdf'
file_name = 

pdfFileObj = open(file_name, 'rb') 
    
# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 
    
# printing number of pages in pdf file 
print(pdfReader.numPages) 
    
# creating a page object 
for page_num in range(pdfReader.numPages):
    print('\nPage :',page_num+1,'\n')
    pageObj = pdfReader.getPage(page_num)
    print(pageObj.extractText())
    words = wordninja.split(pageObj.extractText())
    text = ''
    for word in words:
        text = text + word + ' '
    print(text)
    doc = nlp(text)
    pprint([(X.text, X.label_) for X in doc.ents])
    
# closing the pdf file object 
pdfFileObj.close()
# Out:
# 28
#
# Page : 1
#
# Elios 2 is the most intuitive,
# reliable, and precise indoor
# inspection drone. Keep your
# workforce out of harm™s way
# while performing ˜awless inspections right from the ˚rst ˜ight using cutting edge drone data capture capabilities.ELIOS 2INTUITIVE
# INDOOR
# INSPECTION
# E lios 2 is the most intuitive reliable and precise indoor inspection drone Keep your workforce out of harm s way while performing aw less inspections right from the rst ig ht using cutting edge drone data capture capabilities E LIOS 2 INTUITIVE INDOOR INSPECTION
# [('2', 'CARDINAL')]
#
# Page : 2
#
# 2BUILT FOR
#  YOUR SUCCESS
# Easy maintenanceTraining included
# Dedicated support teamINTUITIVE
#  TO FLY
# GPS-free stabilizationDistance lockFull HD live streamingDESIGNED
#  FOR INDOORCollision-resilientShockproof payloadCon˚ned space accessibilityRobust wireless transmission
# FEATURES
#
# 2 BUILT FOR YOUR SUCCESS Easy maintenance Training included Dedicated support team INTUITIVE TO FLY GPS free stabilization Distance lock Full HD live streaming DESIGNED FOR INDOOR Collision resilient Shockproof payload Con ned space accessibility Robust wireless transmission FEATURES
# [('2', 'CARDINAL'),
#  ('Distance lock Full HD', 'PRODUCT'),
#  ('INDOOR Collision', 'ORG'),
#  ('Shockproof', 'PRODUCT')]
#
# Page : 3
#
# 3DATA
#  PROCESSINGStreamlined data management3D modeling2D measurementDATA
#  QUALITY
# Close up inspection4k CameraThermal camera180° tiltable camera pod10K lumen Adjustable lightingDustproof lightingOblique lightingObstruction-freeFEATURES
#
# 3 DATA PROCESSING Streamlined data management 3 D modeling 2 D measurement DATA QUALITY Close up inspection 4 k Camera Thermal camera 180 tilt able camera pod 10 K lumen Adjustable lighting Dust proof lighting Oblique lighting Obstruction free FEATURES
# [('3', 'CARDINAL'),
#  ('3', 'CARDINAL'),
#  ('2', 'CARDINAL'),
#  ('180', 'CARDINAL'),
#  ('10', 'CARDINAL')]
#
# Page : 4
#
# 4DESIGNED FOR
# CONFINED SPACES
# We believe that robots should be sent in hazardous
# places and dangerous situations instead of humans. Reinventing collision-resilience, Elios 2 allows you to
# capture every corner and inch of the most complex and con˚ned assets, from a safe location.
# 4 DESIGNED FOR CONFINED SPACES We believe that robots should be sent in hazardous places and dangerous situations instead of humans Reinventing collision resilience E lios 2 allows you to capture every corner and inch of the most complex and con ned assets from a safe location
# [('4', 'CARDINAL'), ('2', 'CARDINAL')]
#
# Page : 5
#
# < 40 cm< 15.7 in
# 5ACCESSIBILITY
# With an overall dimension just below 40 cm (15.7 in)
# Elios 2 ˚ts into standard manholes and can enter any space where an inspection is needed. It can safely and easily be ˜own into assets without any human access needed; at no point do workers need to enter
# the space during the inspection.ROBUST TRANSMISSIONPerform remote inspections beyond line of sight,
# through walls and past obstacles with Elios 2. Its wireless transmission system overcomes the needs of indoor con˚gurations and is compatible with the Range Extender for the most complex setups.
# COLLISION RESILIENCEWith a spherical cage protecting propellers from impacts, Elios 2 remains always stable through lightning-fast corrections on the propellers™ speed and direction of rotation. The entire payload is mounted on a retractable structure that protects it from damages in case of frontal shocks.INDOOR CAPABILITIES
#
# 40 cm 15 7 in 5 ACCESSIBILITY With an overall dimension just below 40 cm 15 7 in E lios 2 ts into standard manholes and can enter any space where an inspection is needed It can safely and easily be own into assets without any human access needed at no point do workers need to enter the space during the inspection ROBUST TRANSMISSION Perform remote inspections beyond line of sight through walls and past obstacles with E lios 2 Its wireless transmission system overcomes the needs of indoor con gu rations and is compatible with the Range Extender for the most complex setups COLLISION RESILIENCE With a spherical cage protecting propellers from impacts E lios 2 remains always stable through lightning fast corrections on the propellers speed and direction of rotation The entire payload is mounted on a retractable structure that protects it from damages in case of frontal shocks INDOOR CAPABILITIES
# [('40 cm', 'QUANTITY'),
#  ('5', 'CARDINAL'),
#  ('2', 'CARDINAL'),
#  ('the Range Extender', 'ORG'),
#  ('2', 'CARDINAL')]
#
# Page : 6
#
# 6INTUITIVE
# TO FLY
# Get the job done! Elios 2 intuitive ˜ight experience makes anyone feel like a seasoned pilot from the ˚rst
# ˜ight. Perform ˜awless inspections with an e˛ective
# and user-friendly tool, deployed within minutes.
# 6 INTUITIVE TO FLY Get the job done E lios 2 intuitive ig ht experience makes anyone feel like a seasoned pilot from the rst ig ht Perform aw less inspections with an e ect ive and user friendly tool deployed within minutes
# [('6', 'CARDINAL'), ('2', 'CARDINAL'), ('minutes', 'TIME')]
#
# Page : 7
#
# FULL HD7FLIGHT EXPERIENCEDISTANCE LOCK
# Perform smooth inspections of long and repetitive
# features like welding, or beams. With the distance
# lock, Elios 2 remains at a set distance, ranging from
# 30 cm to 200 cm (1 - 6 ft) autonomously.
# FULL HD LIVE STREAMINGExperience a greater situational awareness and perform live inspections in First-Person View (FPV)
# thanks to the increased details of the Full HD live streaming built into Elios 2.GPS˜FREE STABILIZATION
# Take razor-sharp close-up images in GPS-denied
# environments, in dark and troubled air ˜ows, beyond line of sight. Elios 2 features 7 stability sensors speci˚cally designed for indoor allowing it to hover in place and easily navigate through unstructured spaces.
# FULL HD 7 FLIGHT EXPERIENCE DISTANCE LOCK Perform smooth inspections of long and repetitive features like welding or beams With the distance lock E lios 2 remains at a set distance ranging from 30 cm to 200 cm 1 6 ft autonomously FULL HD LIVE STREAMING Experience a greater situational awareness and perform live inspections in First Person View F PV thanks to the increased details of the Full HD live streaming built into E lios 2 GPS FREE STABILIZATION Take razor sharp close up images in GPS denied environments in dark and troubled air ow s beyond line of sight E lios 2 features 7 stability sensors spec i call y designed for indoor allowing it to hover in place and easily navigate through unstructured spaces
# [('7', 'CARDINAL'),
#  ('2', 'CARDINAL'),
#  ('30 cm to', 'QUANTITY'),
#  ('200 cm 1 6', 'QUANTITY'),
#  ('First Person View', 'FAC'),
#  ('2', 'CARDINAL'),
#  ('7', 'CARDINAL')]
#
# Page : 8
#
# 8
# 8
# [('8', 'CARDINAL')]
#
# Page : 9
#
# 9ACCURATE
# DATA CAPTURE
#
# 9 ACCURATE DATA CAPTURE
# [('9', 'CARDINAL')]
#
# Page : 10
#
# 10THERMAL & 4K CLOSE˜UP INSPECTION
# When it comes to visual inspections, data is what matters.So, we™ve placed Elios 2 payload in the front cage-opening, ˚tted
# with a thermal and a 4K camera side by side. 12MP still and video
# recording gives you stunning detailed images with 0.18 mm/px
# resolution to spot the tiniest cracks from ˜oor to ceiling.
# 10 THERMAL 4 K CLOSE UP INSPECTION When it comes to visual inspections data is what matters So we ve placed E lios 2 payload in the front cage opening t ted with a thermal and a 4 K camera side by side 12 MP still and video recording gives you stunning detailed images with 0 18 mm px resolution to spot the tiniest cracks from o or to ceiling
# [('10', 'CARDINAL'), ('12', 'CARDINAL'), ('0 18 mm', 'QUANTITY')]
#
# Page : 11
#
# 1110K LUMENS
# The Elios 2 features the most powerful and intelligent lighting system ever built on a commercial drone. Carrying 10™000 lumens
# of light, adjustable to your needs, Elios 2 provides the right amount of lighting whether you need to see the big picture or the tiniest crack.
# 1110 K LUMEN S The E lios 2 features the most powerful and intelligent lighting system ever built on a commercial drone Carrying 10 000 lumen s of light adjustable to your needs E lios 2 provides the right amount of lighting whether you need to see the big picture or the tiniest crack
# [('1110 K LUMEN S', 'PERSON'), ('2', 'CARDINAL'), ('10 000 lumen', 'QUANTITY')]
#
# Page : 12
#
# DUSTPROOF LIGHTING12DUSTPROOF LIGHTINGIndustrial indoor spaces are often full of dust, which makes First-
# Person View aircraft navigation di˝cult. Dustproof lighting allows
# you to traverse dirty places without losing sight of your objective.
#
# DUST PROOF LIGHTING 12 DUST PROOF LIGHTING Industrial indoor spaces are often full of dust which makes First Person View aircraft navigation di cult Dust proof lighting allows you to traverse dirty places without losing sight of your objective
# [('DUST PROOF LIGHTING 12 DUST PROOF LIGHTING Industrial', 'ORG'),
#  ('First', 'ORDINAL')]
#
# Page : 13
#
# 13OBLIQUE LIGHTINGTo reveal textures and identify defects, inspectors use a lighting
# technique that creates shadows in asperities. Reproducing this
# technique with our new oblique lighting systems, looking for pitting, cracks, or build-ups becomes as natural as doing it with a ˜ashlight.
# 13 OBLIQUE LIGHTING To reveal textures and identify defects inspectors use a lighting technique that creates shadows in asperities Reproducing this technique with our new oblique lighting systems looking for pitting cracks or build ups becomes as natural as doing it with a ash light
# [('13', 'CARDINAL')]
#
# Page : 14
#
# 14
# 14
# [('14', 'CARDINAL')]
#
# Page : 15
#
# 15BUILD UPON
# ACTIONABLE DATA
#
# 15 BUILD UPON ACTIONABLE DATA
# [('15', 'CARDINAL')]
#
# Page : 16
#
# 16FROM PLANNING TO REPORTING,
# WE™VE GOT YOU COVERED
# Cockpit 2.0 has been designed to let you prepare your inspection
# reports on the ˜y. Once your mission is completed, simply
# connect Elios 2 to your computer using the USB port ˚tted on the drone to import all of your work into Inspector 2.0. From there,
# you will be able to further investigate captured data, document ˚ndings, and create reports.
# 16 FROM PLANNING TO REPORTING WE VE GOT YOU COVERED Cockpit 2 0 has been designed to let you prepare your inspection reports on the y Once your mission is completed simply connect E lios 2 to your computer using the USB port t ted on the drone to import all of your work into Inspector 2 0 From there you will be able to further investigate captured data document n dings and create reports
# [('16', 'CARDINAL'), ('2', 'CARDINAL'), ('USB', 'ORG'), ('2', 'CARDINAL')]
#
# Page : 17
#
# 173D MODELINGSIZABLE INSIGHTS
# Change the way you deliver, visualize,
# and interpret data by building 3D models. Using third-party photogrammetry software such as Pix4D Mapper or Agisoft Photoscan, Elios 2 enables the creation of digital twins which reveals details of your assets.Turn visual information into insights by
# adding ˚gures to features. During data processing in Inspector, simply draw a
# line on the image and you will get a 2D measurement.
# 173 D MODELING SIZABLE INSIGHTS Change the way you deliver visualize and interpret data by building 3 D models Using third party photo gram me try software such as Pix 4 D Mapper or Agi soft Photos can E lios 2 enables the creation of digital twins which reveals details of your assets Turn visual information into insights by adding gur es to features During data processing in Inspector simply draw a line on the image and you will get a 2 D measurement
# [('173', 'CARDINAL'),
#  ('3', 'CARDINAL'),
#  ('third', 'ORDINAL'),
#  ('2', 'CARDINAL')]
#
# Page : 18
#
# 18
# 18
# [('18', 'CARDINAL')]
#
# Page : 19
#
# 19BUILT FOR
# YOUR SUCCESS
# TRAINING INCLUDED
# Because we want you to make the most
# out of your drone, one full day of training is
# o˛ered with each purchase of a unitEASY MAINTENANCE
# Elios 2 is engineered to be easily serviceable, minimizing the reasons to
# ever send your drone back to Flyability.
#  DEDICATED SUPPORT TEAM
# For any assistance, in the ˚eld or at your
# o˝ce, our dedicated support team will
# travel the world for you.
# 19 BUILT FOR YOUR SUCCESS TRAINING INCLUDED Because we want you to make the most out of your drone one full day of training is o ered with each purchase of a unit EASY MAINTENANCE E lios 2 is engineered to be easily serviceable minimizing the reasons to ever send your drone back to Fly ability DEDICATED SUPPORT TEAM For any assistance in the el d or at your o ce our dedicated support team will travel the world for you
# [('19', 'CARDINAL'), ('2', 'CARDINAL')]
#
# Page : 20
#
# 20TECHNICAL SPECIFICATION
# AIRCRAFT
# 20 TECHNICAL SPECIFICATION AIRCRAFT
# [('20', 'CARDINAL')]
#
# Page : 21
#
# 21AIRCRAFTCONFIGURATION
# QuadcopterDIMENSIONSFits in a < 400 mm sphere; 15.75 in
# MOTORS
# 4 fast reversing electric brushless motorsPROPELLERS4 propellers, 5 inchesTAKE˜OFF WEIGHT
# < 1450 g ; < 3,2 lbsIncludes battery, payload &
# protectionMAX FLIGHT TIMEUp to 10 minMAX ASCENT SPEED1.5 m/s ; 5 ft/sMAX DESCENT SPEED1 m/s; 3,3 ft/sMAX SPEED1.3  m/s (Assist Mode) ; 4,25 ft/s4 m/s (Attitude mode) ; 13.12 ft/s
# 6.5 m/s (Sport mode) ; 19.69 ft/s
# MAX PITCH ANGLE
# 0.15 rad (Attitude mode)
#  0.2 rad (Assist Mode)
#  0.3 rad (Sport mode)
# MAX WIND RESISTANCE
# 3 m/s (Assist Mode) ; 9,85 ft/s
#  5 m/s (Sport mode) ; 16,4 ft/sFLIGHT CONTROL SENSORSIMU, magnetometer, barometer, 7
# vision and distance sensorsMATERIALS
# Carbon ˚ber composites, magnesium alloy, aeronautical
# grade aluminum, high-quality thermoplasticsOPERATING TEMP.
# 0 ºC to 50 ºC* ; 32 °F to 122 °FFLIGHT MODESOPTI - Assist Mode ATTI - Attitude mode
#  SPORT - Sport mode
# FAIL SAFE
# Auto-landing on signal lost
# OPERATING
# FREQUENCY
# 2404 Œ 2483 MHz (UAV to RC)
# EIRP2.4 GHz: ˙ 32 dBm (FCC);  ˙20 dBm (CE); ˙10 dBm/MHz (MIC)INGRESS PROTECTION
# Splash and dust resistantNOISE LEVEL99 dB(A) hover120 dB(A) max @ 1m*additional precaution have to be taken
# between 0-10ºC and 40-50ºC. Stability,
# ˜ight performance and ˜ight time might be reduced
# 21 AIRCRAFT CONFIGURATION Quad copter DIMENSIONS Fits in a 400 mm sphere 15 75 in MOTORS 4 fast reversing electric brush less motors PROPELLERS 4 propellers 5 inches TAKE OFF WEIGHT 1450 g 3 2 lbs Includes battery payload protection MAX FLIGHT TIME Up to 10 min MAX ASCENT SPEED 1 5 m s 5 ft s MAX DESCENT SPEED 1 m s 3 3 ft s MAX SPEED 1 3 m s Assist Mode 4 25 ft s 4 m s Attitude mode 13 12 ft s 6 5 m s Sport mode 19 69 ft s MAX PITCH ANGLE 0 15 rad Attitude mode 0 2 rad Assist Mode 0 3 rad Sport mode MAX WIND RESISTANCE 3 m s Assist Mode 9 85 ft s 5 m s Sport mode 16 4 ft s FLIGHT CONTROL SENSORS IMU magneto meter barometer 7 vision and distance sensors MATERIALS Carbon ber composites magnesium alloy aeronautical grade aluminum high quality thermoplastics OPERATING TEMP 0 C to 50 C 32 F to 122 F FLIGHT MODE SO PTI Assist Mode AT TI Attitude mode SPORT Sport mode FAIL SAFE Auto landing on signal lost OPERATING FREQUENCY 2404 2483 MHz U AV to RC E IRP 2 4 GHz 32 dB m FCC 20 dB m CE 10 dB m MHz MIC INGRESS PROTECTION Splash and dust resistant NOISE LEVEL 99 dB A hover 120 dB A max 1 m additional precaution have to be taken between 0 10 C and 40 50 C Stability ig ht performance and ig ht time might be reduced
# [('21', 'CARDINAL'),
#  ('a 400 mm', 'QUANTITY'),
#  ('15 75', 'DATE'),
#  ('4', 'CARDINAL'),
#  ('4', 'CARDINAL'),
#  ('5 inches', 'QUANTITY'),
#  ('Up to 10 min MAX ASCENT SPEED', 'TIME'),
#  ('1 5 m s 5 ft s MAX', 'QUANTITY'),
#  ('3 3 ft s MAX SPEED 1 3 m s', 'QUANTITY'),
#  ('13 12 ft s', 'QUANTITY'),
#  ('6 5 m s', 'QUANTITY'),
#  ('19 69 ft s MAX', 'QUANTITY'),
#  ('0 15', 'CARDINAL'),
#  ('3', 'CARDINAL'),
#  ('MAX WIND', 'PERSON'),
#  ('3 m s', 'QUANTITY'),
#  ('5 m s', 'QUANTITY'),
#  ('16 4 ft s', 'QUANTITY'),
#  ('IMU', 'ORG'),
#  ('7', 'CARDINAL'),
#  ('50', 'CARDINAL'),
#  ('122', 'CARDINAL'),
#  ('2483', 'DATE'),
#  ('RC', 'ORG'),
#  ('2 4 GHz', 'QUANTITY'),
#  ('FCC', 'ORG'),
#  ('20 dB m', 'QUANTITY'),
#  ('99', 'CARDINAL'),
#  ('120 dB A max', 'QUANTITY'),
#  ('40 50', 'CARDINAL')]
#
# Page : 22
#
# 22SMART BATTERY
# RATED CAPACITY
# 5200 mAhNOMINAL VOLTAGE
# 19 VBATTERY TYPE
# LiPo 5S HV Smart Battery:
#  - Improved safety (protection for: overcharge, overcurrent, over/
# under-temperature) - Plug-and-play charging - Self-balancing - Storage self-discharge - State-of-Charge estimation - Cycle counter - Battery IDENERGY
# 98.8 WhCHARGING TIME1.5 hBATTERY CHANGE
# TIME< 1 minCOMPLIANCEApproved for carry-on luggage.
#  Complies with IATA Dangerous
# Good Regulation.
# NET WEIGHT550 g ; 1,2 lbsOPERATING
# TEMPERATURE
# 0-50°C *CHARGING TEMPERATURE
# 10 - 45°C ; 50°F - 113°FMAX CHARGING POWER
# 150 VA AC power
# CHARGERElios 2™s Smart Battery Charger
# PAYLOAD CHASSIS
# PAYLOAD HEAD
# Damped for vibrationsCAMERA POD
# UPWARD TILT
# +90 degreesCAMERA POD
# DOWNWARD TILT
# -90 degreesPAYLOAD
# PROTECTION
# Load limiting mechanism to protect
# the payload in the case of a frontal shock.MAIN CAMERA
# SENSOR1/2.3ﬂ CMOS E˛ective Pixels: 12.3 M
#  Sensitivity: Optimized for low light performancePHOTO FORMATS
# JPGVIDEO FORMATS
# MOV
# VIDEO RECORDING RESOLUTIONS
# 4k Ultra HD: 3840 x 2160 at 30 fps FHD: 1920 x 1080 at 30 fpsVIDEO STREAMING RESOLUTION
# FHD: 1920 x 1080 at 30 fpsMOVIE FOV
# 114° horizontal, 130.8° diagonal
# PHOTO FOV
# 118.8° horizontal, 148.6° diagonal
# TOTAL VERTICAL
# FOV
# approximately 260° including
# camera tilt *additional precaution have to be taken between 0-10ºC
# and 40-50ºC. Stability, ˜ight performance and ˜ight time
# might be reduced.
# 22 SMART BATTERY RATED CAPACITY 5200 mAh NOMINAL VOLTAGE 19 V BATTERY TYPE LiP o 5 S HV Smart Battery Improved safety protection for overcharge over current over under temperature Plug and play charging Self balancing Storage self discharge State of Charge estimation Cycle counter Battery ID ENERGY 98 8 Wh CHARGING TIME 1 5 h BATTERY CHANGE TIME 1 min COMPLIANCE Approved for carry on luggage Complies with IATA Dangerous Good Regulation NET WEIGHT 550 g 1 2 lbs OPERATING TEMPERATURE 0 50 C CHARGING TEMPERATURE 10 45 C 50 F 113 F MAX CHARGING POWER 150 VA AC power CHARGE RE lios 2 s Smart Battery Charger PAYLOAD CHASSIS PAYLOAD HEAD Damped for vibrations CAMERA POD UPWARD TILT 90 degrees CAMERA POD DOWNWARD TILT 90 degrees PAYLOAD PROTECTION Load limiting mechanism to protect the payload in the case of a frontal shock MAIN CAMERA SENSOR 1 2 3 C MOS E ect ive Pixels 12 3 M Sensitivity Optimized for low light performance PHOTO FORMATS JPG VIDEO FORMATS M OV VIDEO RECORDING RESOLUTIONS 4 k Ultra HD 3840 x 2160 at 30 fps F HD 1920 x 1080 at 30 fps VIDEO STREAMING RESOLUTION F HD 1920 x 1080 at 30 fps MOVIE F OV 114 horizontal 130 8 diagonal PHOTO F OV 118 8 horizontal 148 6 diagonal TOTAL VERTICAL F OV approximately 260 including camera tilt additional precaution have to be taken between 0 10 C and 40 50 C Stability ig ht performance and ig ht time might be reduced
# [('22', 'CARDINAL'),
#  ('SMART BATTERY RATED CAPACITY 5200 mAh NOMINAL VOLTAGE 19 V BATTERY TYPE',
#   'ORG'),
#  ('LiP', 'ORG'),
#  ('5 S', 'PERCENT'),
#  ('Cycle', 'ORG'),
#  ('98', 'CARDINAL'),
#  ('1 min COMPLIANCE Approved', 'TIME'),
#  ('Complies', 'LAW'),
#  ('150', 'CARDINAL'),
#  ('VA AC', 'ORG'),
#  ('2', 'CARDINAL'),
#  ('Smart Battery Charger PAYLOAD CHASSIS', 'ORG'),
#  ('90 degrees', 'QUANTITY'),
#  ('90 degrees', 'QUANTITY'),
#  ('PHOTO FORMATS', 'ORG'),
#  ('4', 'CARDINAL'),
#  ('2160', 'CARDINAL'),
#  ('30 fps', 'QUANTITY'),
#  ('1920', 'DATE'),
#  ('1080', 'CARDINAL'),
#  ('30 fps', 'QUANTITY'),
#  ('1920', 'DATE'),
#  ('1080', 'CARDINAL'),
#  ('30 fps', 'QUANTITY'),
#  ('MOVIE F OV', 'ORG'),
#  ('8', 'CARDINAL'),
#  ('148 6', 'PRODUCT'),
#  ('260', 'CARDINAL'),
#  ('40 50', 'CARDINAL')]
#
# Page : 23
#
# 23LENS2.71 mm focal length
#  Fixed focal
# CONTROL MODESAuto mode with manual EV
# compensationFILE STORAGE
# MicroSD card (onboard the aircraft) Max capacity: 128 GB Recommended model: Sandisk
# Extreme micro SDXC UHS-I V30
# SUPPORTED FILE
# SYSTEM
# FAT32 for cards up to 32 GB, exFAT
# for cards bigger than 32 GBTHERMAL CAMERA
# SENSORLepton 3.5 FLIR
# VIDEO RECORDING RESOLUTION
# 160 x 120 at 9 fpsLENSFOV 56° x 42°, Depth of ˚eld 15cm
# to in˚nitySENSITIVITY ˚NEDT˛
# <50 mKWAVELENGTH
# ˚LWIR˛
# 8-14 ˆmLIGHTING SYSTEM
# TYPEHigh-e˝ciency LEDs for even lighting in front, top and bottom, optimized for low impact of dust on picture quality.
#  IR light used for stabilization system.CONTROLFrom remote controller, adaptive
# light beam controlled by camera
# pitchMODESIndirect/dustproof lighting Close up lighting Selective/oblique lightingLIGHT OUTPUT10k lumensOPERATIONAL SAFETY
#  & CRASHWORTHINESS
# NAVIGATION
# LIGHTS
# Green (starboard) and red (port) lights.PROTECTION CAGE
# Carbon ˚ber cage with soft coating, modular subcomponents for maintenance ease, thermoplastic
# elastomer suspensions, front opening dimensioned for easy battery access.COLLISION TOLERANCE
# Uniform all around the drone, up to
# 3 m/s on ˜at objects, up to 1.5 m/s on sharp objects
# 23 LENS 2 71 mm focal length Fixed focal CONTROL MODES Auto mode with manual EV compensation FILE STORAGE MicroSD card onboard the aircraft Max capacity 128 GB Recommended model Sandisk Extreme micro S DXC UH S I V 30 SUPPORTED FILE SYSTEM FAT 32 for cards up to 32 GB exF AT for cards bigger than 32 GB THERMAL CAMERA SENSOR Lepton 3 5 FLI R VIDEO RECORDING RESOLUTION 160 x 120 at 9 fps LENS F OV 56 x 42 Depth of el d 15 cm to in n it y SENSITIVITY NED T 50 mK WAVELENGTH L WIR 8 14 m LIGHTING SYSTEM TYPE High e cie n cy LEDs for even lighting in front top and bottom optimized for low impact of dust on picture quality IR light used for stabilization system CONTROL From remote controller adaptive light beam controlled by camera pitch MODES Indirect dust proof lighting Close up lighting Selective oblique lighting LIGHT OUTPUT 10 k lumen s OPERATIONAL SAFETY CRASH WORTHINESS NAVIGATION LIGHTS Green starboard and red port lights PROTECTION CAGE Carbon ber cage with soft coating modular sub components for maintenance ease thermoplastic e last omer suspensions front opening dimension ed for easy battery access COLLISION TOLERANCE Uniform all around the drone up to 3 m s on at objects up to 1 5 m s on sharp objects
# [('23', 'CARDINAL'),
#  ('EV', 'ORG'),
#  ('Max', 'PRODUCT'),
#  ('128', 'CARDINAL'),
#  ('Sandisk Extreme', 'ORG'),
#  ('32', 'CARDINAL'),
#  ('32', 'CARDINAL'),
#  ('FLI R VIDEO', 'ORG'),
#  ('160', 'CARDINAL'),
#  ('120', 'CARDINAL'),
#  ('9 fps', 'QUANTITY'),
#  ('15 cm', 'QUANTITY'),
#  ('NED', 'ORG'),
#  ('mK WAVELENGTH L WIR', 'ORG'),
#  ('IR', 'ORG'),
#  ('Selective', 'WORK_OF_ART'),
#  ('3 m s', 'QUANTITY'),
#  ('1 5 m', 'QUANTITY')]
#
# Page : 24
#
# 24TECHNICAL SPECIFICATION
# GROUND CONTROL STATION
#
# 24 TECHNICAL SPECIFICATION GROUND CONTROL STATION
# [('24', 'CARDINAL')]
#
# Page : 25
#
# 25REMOTE CONTROLLER
# OPERATING
# FREQUENCIES2404 - 2483 MHz (RC to UAV)
#  5738 - 5808 MHz (RC to RC) 920.6 - 928 MHz (RC to RC, Japan
# only)MAX TRANSMISSION DISTANCE
# Up to 500 m in direct line of sightEIRP2.4 Ghz ˙20 dBm, 5.8 GHz ˙13 dBm, 920 MHz ˙10 dBmWEIGHT810 g (924 g with tablet holder)OPERATING TEMP.
# 0 °C to 40 °COUTPUT PORT
# HDMI, SDI, USBBATTERY
# 6000 mAh 2SCONTROLSAircraft control and payload settingsOPTIONSOptional remote controller (camera operator) with video stream reception on a secondary screen, and dual control of camera settings.BATTERY CHARGER
# 17.4 V / 57 W
# TABLET
# MODELSamsung Galaxy Tab Active 2
# BATTERY CHARGER
# USB Charger 5VOPERATING TEMP.
# -15 °C to 40 °CCHARGING TEMP.
# -15 °C to 40 °CCHARGING TIME5 hoursWORKING TIME
# 5 hours (when receiving video stream) to 76 hours (idle)WEIGHT415 g
# 25 REMOTE CONTROLLER OPERATING FREQUENCIES 2404 2483 MHz RC to U AV 5738 5808 MHz RC to RC 920 6 928 MHz RC to RC Japan only MAX TRANSMISSION DISTANCE Up to 500 m in direct line of sight E IRP 2 4 Ghz 20 dB m 5 8 GHz 13 dB m 920 MHz 10 d BmW EIGHT 810 g 924 g with tablet holder OPERATING TEMP 0 C to 40 C OUTPUT PORT HDMI SDI USB BATTERY 6000 mAh 2 S CONTROLS Aircraft control and payload settings OPTIONS Optional remote controller camera operator with video stream reception on a secondary screen and dual control of camera settings BATTERY CHARGER 17 4 V 57 W TABLET MODEL Samsung Galaxy Tab Active 2 BATTERY CHARGER USB Charger 5 V OPERATING TEMP 15 C to 40 C CHARGING TEMP 15 C to 40 C CHARGING TIME 5 hours WORKING TIME 5 hours when receiving video stream to 76 hours idle WEIGHT 415 g
# [('25', 'CARDINAL'),
#  ('2483', 'DATE'),
#  ('RC', 'ORG'),
#  ('RC', 'ORG'),
#  ('RC', 'ORG'),
#  ('920 6 928', 'MONEY'),
#  ('RC Japan', 'ORG'),
#  ('MAX TRANSMISSION DISTANCE', 'FAC'),
#  ('Up to', 'CARDINAL'),
#  ('920', 'CARDINAL'),
#  ('924', 'CARDINAL'),
#  ('40', 'CARDINAL'),
#  ('HDMI SDI USB BATTERY', 'ORG'),
#  ('6000', 'CARDINAL'),
#  ('mAh 2 S CONTROLS Aircraft', 'ORG'),
#  ('17', 'CARDINAL'),
#  ('W TABLET', 'WORK_OF_ART'),
#  ('Samsung', 'ORG'),
#  ('2', 'CARDINAL'),
#  ('CHARGER', 'ORG'),
#  ('40', 'CARDINAL'),
#  ('40', 'CARDINAL'),
#  ('5 hours', 'TIME'),
#  ('5 hours', 'TIME'),
#  ('76 hours', 'TIME'),
#  ('415', 'CARDINAL')]
#
# Page : 26
#
# 26TECHNICAL SPECIFICATION
# ACCESSORIES & SOFTWARE
#
# 26 TECHNICAL SPECIFICATION ACCESSORIES SOFTWARE
# [('26', 'CARDINAL')]
#
# Page : 27
#
# 27TRANSPORT CASE
# DIMENSIONS61 x 44 x 53 cmWEIGHT11.5 kg
# COMPLIANCEIATA compliant for checked-in
# luggage.
# COCKPIT SOFTWARE
# FEATURES
# Real time video and UAV telemetry,
# status visualization (remaining battery, payload settings, warnings,
# etc. ), control payload settings and various con˚gurations.OPERATING
# SYSTEM
# Android. Optimized for tablet provided with UAV system
# INSPECTOR SOFTWARE
# FEATURES
# Video and thermal video viewer (frame by frame), ˜ight log analysis including point of interests recorded during ˜ight, screenshots and ˜ight data export.OPERATING
# SYSTEM
# Windows 7, 8 and 10 (32 and 64 bits)
#
# 27 TRANSPORT CASE DIMENSIONS 61 x 44 x 53 cm WEIGHT 11 5 kg COMPLIANCE IATA compliant for checked in luggage COCKPIT SOFTWARE FEATURES Real time video and U AV telemetry status visualization remaining battery payload settings warnings etc control payload settings and various con gu rations OPERATING SYSTEM Android Optimized for tablet provided with U AV system INSPECTOR SOFTWARE FEATURES Video and thermal video viewer frame by frame ig ht log analysis including point of interests recorded during ig ht screenshots and ig ht data export OPERATING SYSTEM Windows 7 8 and 10 32 and 64 bits
# [('27', 'CARDINAL'),
#  ('61', 'CARDINAL'),
#  ('53 cm WEIGHT 11 5 kg', 'QUANTITY'),
#  ('IATA', 'ORG'),
#  ('INSPECTOR SOFTWARE FEATURES Video', 'ORG'),
#  ('64', 'CARDINAL')]
#
# Page : 28
#
# Flyability is a Swiss company building solutions for the inspection and exploration of indoor, inaccessible,
# and con˚ned spaces. By allowing drones to be used safely inside buildings, it enables industrial companies and inspection professionals to reduce downtime, inspection costs, and risks to workers.
# With hundreds of customers in over 50 countries in Power Generation, Oil & Gas, Chemicals, Maritime,
# Infrastructures & Utilities, and Public Safety, Flyability
# has pioneered and continues to lead the innovation in the commercial indoor drone space.
# Flyability SAEPFL Innovation Park Š Building C
# 1015 Lausanne, Switzerland
# +41 21 311 55 00sales@flyability.com
# WWW.FLYABILITY.COM/
# ELIOS˜2
# Fly ability is a Swiss company building solutions for the inspection and exploration of indoor inaccessible and con ned spaces By allowing drones to be used safely inside buildings it enables industrial companies and inspection professionals to reduce downtime inspection costs and risks to workers With hundreds of customers in over 50 countries in Power Generation Oil Gas Chemicals Maritime Infrastructures Utilities and Public Safety Fly ability has pioneered and continues to lead the innovation in the commercial indoor drone space Fly ability S A EP FL Innovation Park Building C 1015 Lausanne Switzerland 41 21 311 55 00 sales fly ability com WWW FLY ABILITY COM E LIOS 2
# [('Swiss', 'NORP'),
#  ('hundreds', 'CARDINAL'),
#  ('50', 'CARDINAL'),
#  ('Power Generation Oil Gas Chemicals Maritime Infrastructures Utilities',
#   'ORG'),
#  ('Fly ability S A EP FL Innovation Park Building C', 'ORG'),
#  ('Lausanne', 'GPE'),
#  ('Switzerland', 'GPE')]

# %%
from pprint import pprint
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_lg
nlp = en_core_web_lg.load()

# %%
for page_num in range(pdfReader.numPages):
    print('\nPage :',page_num+1,'\n')
    pageObj = pdfReader.getPage(page_num)
    doc = nlp(pageObj.extractText())
    pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# Page : 1
#
# [('Elios 2', 'PERSON'), ('˚rst', 'PRODUCT'), ('2INTUITIVE', 'CARDINAL')]
#
# Page : 2
#
# [('2BUILT', 'PERSON'), ('INDOORCollision', 'NORP')]
#
# Page : 3
#
# [('PROCESSINGStreamlined', 'ORG'),
#  ('management3D modeling2D measurementDATA \n ', 'PERSON')]
#
# Page : 4
#
# [('Elios 2', 'PERSON'), ('con˚ned', 'ORG')]
#
# Page : 5
#
# [('40 cm', 'QUANTITY'),
#  ('15.7', 'CARDINAL'),
#  ('TRANSMISSIONPerform', 'LOC'),
#  ('the Range Extender', 'ORG'),
#  ('Elios 2', 'PERSON')]
#
# Page : 6
#
# [('Elios 2', 'PERSON'), ('˚rst', 'PRODUCT'), ('minutes', 'TIME')]
#
# Page : 7
#
# [('Elios 2', 'PERSON'),
#  ('200 cm', 'QUANTITY'),
#  ('STREAMINGExperience', 'ORG'),
#  ('Elios 2.GPS˜FREE STABILIZATION', 'LOC'),
#  ('2', 'CARDINAL'),
#  ('7', 'CARDINAL')]
#
# Page : 8
#
# [('8', 'CARDINAL')]
#
# Page : 9
#
# [('9ACCURATE', 'CARDINAL')]
#
# Page : 10
#
# [('10THERMAL', 'CARDINAL'), ('0.18 mm', 'QUANTITY')]
#
# Page : 11
#
# [('10™000 lumens', 'QUANTITY')]
#
# Page : 12
#
# [('DUSTPROOF LIGHTING12DUSTPROOF', 'PERSON'), ('Dustproof', 'PERSON')]
#
# Page : 13
#
# [('13OBLIQUE', 'CARDINAL'), ('LIGHTINGTo', 'ORG')]
#
# Page : 14
#
# [('14', 'CARDINAL')]
#
# Page : 15
#
# [('15BUILD', 'CARDINAL')]
#
# Page : 16
#
# [('16FROM', 'CARDINAL'), ('USB', 'ORG')]
#
# Page : 17
#
# [('173D', 'CARDINAL'),
#  ('MODELINGSIZABLE', 'ORG'),
#  ('third', 'ORDINAL'),
#  ('Agisoft Photoscan', 'PERSON'),
#  ('Elios 2', 'PERSON'),
#  ('2D', 'CARDINAL')]
#
# Page : 18
#
# [('18', 'CARDINAL')]
#
# Page : 19
#
# [('19BUILT', 'CARDINAL'),
#  ('one full day', 'DATE'),
#  ('unitEASY', 'ORG'),
#  ('Flyability', 'ORG'),
#  ('o˝ce', 'PRODUCT')]
#
# Page : 20
#
# [('20TECHNICAL', 'CARDINAL')]
#
# Page : 21
#
# [('21AIRCRAFTCONFIGURATION\nQuadcopterDIMENSIONSFits', 'MONEY'),
#  ('400 mm', 'QUANTITY'),
#  ('15.75', 'CARDINAL'),
#  ('4', 'CARDINAL'),
#  ('5', 'CARDINAL'),
#  ('3,2', 'CARDINAL'),
#  ('lbsIncludes', 'ORG'),
#  ('10 minMAX', 'QUANTITY'),
#  ('5', 'CARDINAL'),
#  ('3,3', 'CARDINAL'),
#  ('4,25', 'PRODUCT'),
#  ('s4 m/s', 'PRODUCT'),
#  ('13.12 ft', 'QUANTITY'),
#  ('19.69', 'CARDINAL'),
#  ('9,85', 'ORG'),
#  ('SENSORSIMU', 'ORG'),
#  ('7', 'CARDINAL'),
#  ('32 °', 'QUANTITY'),
#  ('122 °', 'QUANTITY'),
#  ('FFLIGHT MODESOPTI - Assist Mode ATTI', 'ORG'),
#  ('FREQUENCY\n2404 Œ 2483', 'ORG'),
#  ('RC', 'ORG'),
#  ('EIRP2.4', 'PERSON'),
#  ('GHz', 'CARDINAL'),
#  ('32 dBm', 'QUANTITY'),
#  ('FCC', 'ORG'),
#  ('CE', 'ORG'),
#  ('1m*additional', 'CARDINAL'),
#  ('40-50ºC.', 'QUANTITY')]
#
# Page : 22
#
# [('22SMART', 'CARDINAL'),
#  ('5S', 'DATE'),
#  ('Smart Battery', 'ORG'),
#  ('WhCHARGING TIME1.5 hBATTERY', 'PERSON'),
#  ('1', 'CARDINAL'),
#  ('IATA Dangerous \nGood Regulation', 'ORG'),
#  ('1,2', 'CARDINAL'),
#  ('10 - 45°', 'QUANTITY'),
#  ('50°', 'QUANTITY'),
#  ('FMAX', 'ORG'),
#  ('150', 'CARDINAL'),
#  ('VA AC', 'ORG'),
#  ('CHARGERElios 2', 'PRODUCT'),
#  ('Smart Battery Charger\nPAYLOAD CHASSIS\n', 'ORG'),
#  ('Damped for', 'WORK_OF_ART'),
#  ('vibrationsCAMERA POD \nUPWARD TILT\n+90 degreesCAMERA POD \n', 'ORG'),
#  ('CMOS E˛ective', 'PRODUCT'),
#  ('12.3', 'CARDINAL'),
#  ('performancePHOTO FORMATS', 'PERSON'),
#  ('MOV\nVIDEO', 'ORG'),
#  ('2160', 'CARDINAL'),
#  ('30 fps', 'QUANTITY'),
#  ('FHD', 'ORG'),
#  ('1920', 'DATE'),
#  ('1080', 'CARDINAL'),
#  ('30 fpsVIDEO STREAMING RESOLUTION', 'QUANTITY'),
#  ('FHD', 'ORG'),
#  ('1920', 'DATE'),
#  ('1080', 'CARDINAL'),
#  ('30', 'CARDINAL'),
#  ('130.8°', 'QUANTITY'),
#  ('118.8°', 'QUANTITY'),
#  ('148.6°', 'QUANTITY'),
#  ('0-10ºC', 'CARDINAL')]
#
# Page : 23
#
# [('CONTROL MODESAuto', 'ORG'),
#  ('EV \ncompensationFILE STORAGE', 'ORG'),
#  ('Max', 'PERSON'),
#  ('128', 'CARDINAL'),
#  ('exFAT', 'ORG'),
#  ('GBTHERMAL', 'ORG'),
#  ('FLIR\nVIDEO', 'ORG'),
#  ('160', 'CARDINAL'),
#  ('120', 'CARDINAL'),
#  ('9 fpsLENSFOV 56° x 42°', 'QUANTITY'),
#  ('Depth of ˚eld', 'ORG'),
#  ('15cm', 'QUANTITY'),
#  ('mKWAVELENGTH \n˚LWIR˛', 'PERSON'),
#  ('CONTROLFrom', 'PERSON'),
#  ('Selective', 'WORK_OF_ART'),
#  ('lumensOPERATIONAL SAFETY\n & CRASHWORTHINESS\n', 'ORG'),
#  ('1.5 m', 'QUANTITY')]
#
# Page : 24
#
# [('24TECHNICAL', 'CARDINAL')]
#
# Page : 25
#
# [('25REMOTE', 'CARDINAL'),
#  ('RC', 'ORG'),
#  ('RC', 'ORG'),
#  ('RC', 'ORG'),
#  ('920.6', 'CARDINAL'),
#  ('RC', 'ORG'),
#  ('RC', 'GPE'),
#  ('Japan', 'GPE'),
#  ('Ghz ˙20 dBm', 'PERSON'),
#  ('5.8 GHz', 'QUANTITY'),
#  ('920', 'CARDINAL'),
#  ('924', 'CARDINAL'),
#  ('40 °', 'QUANTITY'),
#  ('COUTPUT PORT\nHDMI', 'FAC'),
#  ('USBBATTERY', 'ORG'),
#  ('17.4', 'CARDINAL'),
#  ('MODELSamsung Galaxy Tab', 'PERSON'),
#  ('2', 'CARDINAL'),
#  ('USB Charger', 'ORG'),
#  ('5VOPERATING', 'CARDINAL'),
#  ('40 °', 'QUANTITY'),
#  ('CCHARGING TEMP', 'ORG'),
#  ('40 °', 'QUANTITY'),
#  ('CCHARGING TIME5 hoursWORKING TIME', 'ORG'),
#  ('76 hours', 'TIME')]
#
# Page : 26
#
# [('26TECHNICAL', 'CARDINAL')]
#
# Page : 27
#
# [('27TRANSPORT', 'CARDINAL'),
#  ('8', 'DATE'),
#  ('10', 'CARDINAL'),
#  ('32', 'CARDINAL'),
#  ('64', 'CARDINAL')]
#
# Page : 28
#
# [('Flyability', 'ORG'),
#  ('Swiss', 'NORP'),
#  ('con˚ned', 'ORG'),
#  ('hundreds', 'CARDINAL'),
#  ('50', 'CARDINAL'),
#  ('Power Generation, Oil & Gas, Chemicals, Maritime', 'ORG'),
#  ('Infrastructures & Utilities', 'ORG'),
#  ('Public Safety', 'ORG'),
#  ('Flyability \n', 'ORG'),
#  ('Lausanne', 'GPE'),
#  ('Switzerland', 'GPE'),
#  ('21', 'CARDINAL'),
#  ('55', 'CARDINAL')]

# %%
from math import log

# Build a cost dictionary, assuming Zipf's law and cost = -math.log(probability).
words = open("words-by-frequency.txt").read().split()
wordcost = dict((k, log((i+1)*log(len(words)))) for i,k in enumerate(words))
maxword = max(len(x) for x in words)

def infer_spaces(s):
    """Uses dynamic programming to infer the location of spaces in a string
    without spaces."""

    # Find the best match for the i first characters, assuming cost has
    # been built for the i-1 first characters.
    # Returns a pair (match_cost, match_length).
    def best_match(i):
        candidates = enumerate(reversed(cost[max(0, i-maxword):i]))
        return min((c + wordcost.get(s[i-k-1:i], 9e999), k+1) for k,c in candidates)

    # Build the cost array.
    cost = [0]
    for i in range(1,len(s)+1):
        c,k = best_match(i)
        cost.append(c)

    # Backtrack to recover the minimal-cost string.
    out = []
    i = len(s)
    while i>0:
        c,k = best_match(i)
        assert c == cost[i]
        out.append(s[i-k:i])
        i -= k

    return " ".join(reversed(out))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-e7efb4d8bc9e> in <module>
#       2
#       3 # Build a cost dictionary, assuming Zipf's law and cost = -math.log(probability).
# ----> 4 words = open("words-by-frequency.txt").read().split()
#       5 wordcost = dict((k, log((i+1)*log(len(words)))) for i,k in enumerate(words))
#       6 maxword = max(len(x) for x in words)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'words-by-frequency.txt'

# %%
import wordninja
wordninja.split('iamalittleteapotshortandstout')
# Out:
# ['iam', 'a', 'little', 'teapot', 'short', 'and', 'stout']
